# %% [markdown]
# #Machine Learning with scikit-learn

# %%
for i in range(0,100):
    if (i% 3 ==0):
        print('fizz')
    elif (i%5==0):
        print('fuzz')
    elif (i&15 == 0):
        print('fizzfuzz')
    else:
        print(i)
# Out:
# fizz
# 1
# 2
# fizz
# 4
# fuzz
# fizz
# 7
# 8
# fizz
# fuzz
# 11
# fizz
# 13
# 14
# fizz
# fizzfuzz
# 17
# fizz
# 19
# fuzz
# fizz
# 22
# 23
# fizz
# fuzz
# 26
# fizz
# 28
# 29
# fizz
# 31
# fizzfuzz
# fizz
# 34
# fuzz
# fizz
# 37
# 38
# fizz
# fuzz
# 41
# fizz
# 43
# 44
# fizz
# 46
# 47
# fizz
# 49
# fuzz
# fizz
# 52
# 53
# fizz
# fuzz
# 56
# fizz
# 58
# 59
# fizz
# 61
# 62
# fizz
# fizzfuzz
# fuzz
# fizz
# 67
# 68
# fizz
# fuzz
# 71
# fizz
# 73
# 74
# fizz
# 76
# 77
# fizz
# 79
# fuzz
# fizz
# 82
# 83
# fizz
# fuzz
# 86
# fizz
# 88
# 89
# fizz
# 91
# 92
# fizz
# 94
# fuzz
# fizz
# 97
# 98
# fizz
