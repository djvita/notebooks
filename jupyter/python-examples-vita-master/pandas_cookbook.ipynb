# %% [markdown]
# # Pandas Library
# Pandas is a library used for data manipulation and analysis. Pandas offers data structures and operations for creating and manipulating Data [Series](http://pandas.pydata.org/pandas-docs/dev/generated/pandas.Series.html) and [DataFrame](http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html) objects. Data can be imported from various data sources, e.g., [Numpy](http://www.numpy.org/) arrays, Python dictionaries and CSV files. Pandas allows you to manipulate, organize and display the data.
# <div class="alert alert-block alert-info" style="margin-top: 20px">**Note:**
# This cookbook is based on the examples and tutorials from the [Pandas Homepage](http://pandas.pydata.org).
# </div>
#
# ##  Install pandas
# ```!pip install pandas```

# %%
#<help:pandas_setup>
import pandas as pd
pd.__version__
# Out:
# '1.4.3'

# %% [markdown]
# ### Create a series
# Series are one dimensional arrays capable of holding any array type. The axis labels are known as the **index**. The index must be the same length as the amount of values passed. Pass a list of values to a series.

# %%
#<help:series_create>
import pandas as pd
import numpy as np
s = pd.Series([1.5,3,5,np.nan,5,9])
s
# Out:
# 0    1.5
# 1    3.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    9.0
# dtype: float64

# %% [markdown]
# ### DataFrames
#
# A DataFrame is two-dimensional. Columns can be of different data types.
# DataFrames accept many data inputs including series and other DataFrames.
# You can pass indexes (row labels) and columns (column labels). Indexes can be numbers, dates, or strings/tuples.

# %%
#<help:dataframe_setup>
import pandas as pd
dates = pd.date_range('20140102',periods=4)
dates
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-04', '2014-01-05'], dtype='datetime64[ns]', freq='D')

# %% [markdown]
# Create the DataFrame by adding the values, set the index and columns.

# %%
#<help:dataframe_create>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df
# Out:
#                    A         B         C         D         E
# 2014-01-02 -0.273250  0.654986  1.019324 -0.251753  0.939615
# 2014-01-03  0.163421 -0.940736  0.130345  1.171372  0.182207
# 2014-01-04  0.844743 -0.515715 -2.088358  0.608983  2.193545
# 2014-01-05 -0.232477  0.685044  1.522682  0.640780  1.189990

# %% [markdown]
# ###Displaying Data
#
# See the top and bottom rows of the DataFrame with  `head()` and `tail()`. You can configure the number of rows that `head` and `tail` show by passing a parameter value. The default (without parameter) is `5`. See the index columns and values with `data_frame.index`, `data_frame.columns` and `data_frame.values` respectively.

# %%
#<help:dataframe_head>
import pandas as pd
import numpy as np
dates = pd.date_range('20140402',periods=6)
df = pd.DataFrame(np.random.randn(6,5),index=dates,columns=list('ABCDE'))
df.head()
# Out:
#                    A         B         C         D         E
# 2014-04-02  0.898138 -0.595031 -1.556465  2.206674  1.399054
# 2014-04-03  0.019209 -0.822607  0.222221 -0.192158  1.702242
# 2014-04-04 -0.559454 -0.784411 -0.607387 -0.651318  1.846168
# 2014-04-05 -1.063254  1.041936  0.515916  0.058183  0.167096
# 2014-04-06 -1.046676 -1.518813 -0.854082 -1.233042  2.032569

# %%
#<help:dataframe_tail>
import pandas as pd
import numpy as np
dates = pd.date_range('20140501',periods=6)
df = pd.DataFrame(np.random.randn(6,5),index=dates,columns=list('ABCDE'))
df.tail()
# Out:
#                    A         B         C         D         E
# 2014-05-02 -0.123161  1.557111 -1.667519 -1.136810  1.875344
# 2014-05-03 -2.204413  0.348758  0.608354  0.674327 -0.817089
# 2014-05-04 -0.306543  0.001877  0.874361 -0.451164 -0.480495
# 2014-05-05  0.479370 -0.608081  0.751531 -1.739521 -0.940699
# 2014-05-06  1.445063 -0.197510 -1.185841 -1.051144 -0.597520

# %%
#<help:dataframe_get_index>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-01-02, ..., 2014-01-05]
# Length: 4, Freq: D, Timezone: None

# %% [markdown]
# For specific values:

# %%
#<help:dataframe_get_columns>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.columns
# Out:
# Index([u'A', u'B', u'C', u'D', u'E'], dtype='object')

# %%
#<help:dataframe_get_values>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.values
# Out:
# array([[-0.50904859,  0.26295515,  0.04207007,  0.29842854,  2.07838144],
#        [ 0.94803045, -0.58066146, -0.95550109, -1.73191989, -0.87643787],
#        [ 1.81544287,  0.90052961, -0.30079788,  0.88394052,  0.04402755],
#        [ 1.37095972,  0.29015974,  0.09753185, -0.55144965, -0.80161671]])

# %% [markdown]
# ###Show statistical information about your DataFrame
#
# Use `.describe()` to display the mean, median, variance etc. of your DataFrame.

# %%
#<help:dataframe_describe>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.describe()
# Out:
#               A         B         C         D         E
# count  4.000000  4.000000  4.000000  4.000000  4.000000
# mean   0.157800  0.295975  0.548927 -0.823547  0.518206
# std    0.913227  0.644773  0.470688  1.208504  0.642345
# min   -0.464791 -0.512131 -0.037483 -2.340489 -0.137342
# 25%   -0.395597 -0.002711  0.348755 -1.281177  0.096919
# 50%   -0.201312  0.334166  0.566268 -0.777612  0.441558
# 75%    0.352085  0.632852  0.766440 -0.319982  0.862845
# max    1.498613  1.027699  1.100655  0.601527  1.327049

# %% [markdown]
# ###Transpose Data
#
# Switch rows with columns easily using `DataFrame.T`.

# %%
#<help:dataframe_transpose>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.T
# Out:
#    2014-01-02  2014-01-03  2014-01-04  2014-01-05
# A    0.844201    0.351914    0.457134   -1.225624
# B    1.198438   -1.177685   -0.328065   -0.775237
# C   -0.044542    0.278006    1.025507   -0.003791
# D    0.832144   -0.645775    0.162224   -0.252110
# E   -0.701110    1.474042   -0.938700   -0.687980

# %% [markdown]
# ###Sort by an Axis

# %%
#<help:dataframe_sort_axis>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.sort_index(axis=1, ascending=True)
# Out:
#                    A         B         C         D         E
# 2014-01-02  0.645276  0.972345  0.606225  1.721559 -0.586960
# 2014-01-03 -1.560375  0.633303  2.153168  0.986635  0.898647
# 2014-01-04  2.532548 -0.304545  0.073760  1.311735 -1.336317
# 2014-01-05  0.099489 -1.391138  0.974005  2.177076  1.134903

# %% [markdown]
# ###Sort by Values

# %%
#<help:dataframe_sort_value>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.sort(columns='B')
# Out:
#                    A         B         C         D         E
# 2014-01-04  1.243236 -0.492448 -0.211561  1.305207 -1.273432
# 2014-01-03  0.339732  0.367511  1.526918  1.556023  1.718439
# 2014-01-02 -0.123535  1.177169 -0.384346 -1.253320  1.258342
# 2014-01-05 -0.099620  1.595678 -1.079167 -0.006257  0.667836

# %% [markdown]
# #Selection
# Find and select data, slice, locate by columns or values. These operations make pandas very similar to SQL in terms of querying information. The `.loc` attribute is the primary access method. The following are valid inputs:
#
# * A single label, e.g. `5` or 'a' (Note that `5` is interpreted as a label of the index. This use is not an integer position along the index.)
# * A list or array of labels ['a', 'b', 'c']
# * A slice object with labels 'a':'f' (note that contrary to usual python slices, both the start and the stop are included!)
# * A boolean array
#
# Select a single column from its defined label name.

# %%
#<help:dataframe_select_single_column>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df['E']
# Out:
# 2014-01-02   -1.389612
# 2014-01-03   -0.122942
# 2014-01-04   -1.184034
# 2014-01-05   -1.611220
# Freq: D, Name: E, dtype: float64

# %% [markdown]
# Slice like a dictionary to get a certain number of rows only.

# %%
#<help:dataframe_slice>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df[1:4]
# Out:
#                    A         B         C         D         E
# 2014-01-03 -0.537264  2.476751  0.400489 -1.678059  1.042632
# 2014-01-04  0.221088 -1.632433  0.233838  0.098460  0.354022
# 2014-01-05 -1.150945 -0.413615  1.370128  1.010409 -1.350117

# %% [markdown]
# **Select by Label**
#
# Get certain rows and columns.

# %%
#<help:dataframe_select_by_label_row_number>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc[dates[2]]
# Out:
# A   -0.572218
# B    0.065071
# C   -0.606708
# D   -0.453218
# E   -1.348405
# Name: 2014-01-04 00:00:00, dtype: float64

# %%
#<help:dataframe_select_by_label_columns>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc[:,['B','D']]
# Out:
#                    B         D
# 2014-01-02 -0.576354  0.800356
# 2014-01-03  1.938135 -0.254918
# 2014-01-04  0.189858  2.287591
# 2014-01-05 -0.350382  0.295642

# %%
#<help:dataframe_select_by_label_slicing>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc['20140102':'20140104',['B','E']]
# Out:
#                    B         E
# 2014-01-02  0.084960  0.508089
# 2014-01-03  0.105333 -0.732693
# 2014-01-04  0.799113 -0.165392

# %%
#<help:dataframe_reduce_dimensions_object>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc['20140102',['A','D']]
# Out:
# A   -0.694383
# D   -1.120381
# Name: 2014-01-02 00:00:00, dtype: float64

# %% [markdown]
# **Select a Scalar Value**

# %%
#<help:dataframe_select_scalar_value>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc[dates[0],'E']
# Out:
# 2.650967032078702

# %% [markdown]
# You can also use `at` to locate scalar values.

# %%
#<help:dataframe_select_scalar_value>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.at[dates[0],'C']
# Out:
# -1.7177038299667136

# %% [markdown]
# ###Selection by Position of DataFrame

# %%
#<help:dataframe_select_position>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[3]
# Out:
# A    0.017220
# B    1.817573
# C    0.005224
# D    0.759686
# E   -2.070567
# Name: 2014-01-05 00:00:00, dtype: float64

# %% [markdown]
# **Select by scalar value**

# %%
#<help:dataframe_select_scalar_value>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2014-01-05  0.467596 -0.640228

# %%
#<help:dataframe_select_scalar_value>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[[1,2,3],[0,2]]
# Out:
#                    A         C
# 2014-01-03  1.452039  2.270444
# 2014-01-04 -1.636686  0.365372
# 2014-01-05 -0.975686 -1.103772

# %% [markdown]
# **Slice**

# %%
#<help:dataframe_slice_rows>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[1:3,:]
# Out:
#                    A         B         C         D         E
# 2014-01-03  0.290365  0.909752  0.302261 -0.915917 -0.374688
# 2014-01-04  0.421410  1.327861 -0.339247  1.023343 -1.621126

# %%
#<help:dataframe_slice_columns>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[:,1:3]
# Out:
#                    B         C
# 2014-01-02 -0.184349  2.390271
# 2014-01-03 -1.927494 -0.568760
# 2014-01-04 -0.201383 -2.241768
# 2014-01-05  0.426133 -0.293509

# %% [markdown]
# **Obtain an explicit value**

# %%
#<help:dataframe_obtain_value_explicit>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iloc[1,1]
# Out:
# -0.38371230891910585

# %%
#<help:dataframe_obtain_value_explicit>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iat[1,1]
# Out:
# -0.45979582267428132

# %% [markdown]
# **Boolean Indexing**

# %%
#<help:dataframe_boolean_single_column>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df[df.A > 0]
# Out:
#                    A         B         C         D         E
# 2014-01-03  0.799757 -1.231067 -0.393633 -0.268086  0.755336

# %% [markdown]
# **Where keyword like SQL**

# %%
#<help:dataframe_where>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df[df > 0]
# Out:
#                    A         B         C         D         E
# 2014-01-02       NaN       NaN  1.290481  0.933880  0.025136
# 2014-01-03  1.103705       NaN  0.005192  0.928906       NaN
# 2014-01-04  0.051708  0.481248       NaN  0.424343  0.638357
# 2014-01-05  0.399129  2.164095       NaN       NaN       NaN

# %% [markdown]
# **Filter to a single string**

# %%
#<help:dataframe_where>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)

df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})
df[df['A'] == 'foo']
# Out:
#      A      B         C         D
# 0  foo    one  0.223785  0.026267
# 2  foo    two  1.324954  0.415970
# 4  foo    two -1.273748 -0.062261
# 6  foo    one  3.370689  0.718423
# 7  foo  three -0.455092 -0.368484

# %% [markdown]
# **Filter to multiple strings**

# %%
#<help:dataframe_where>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)

df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})
df[(df['A'] == 'foo') & (df['B'] == 'one')]
# Out:
#      A    B         C         D
# 0  foo  one -0.932120 -1.812426
# 6  foo  one -1.585005 -1.032028

# %% [markdown]
# **Is in to filter**

# %%
#<help:dataframe_isin_filter>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df2 = df.copy()
df2['F']=['one', 'two','three','four']
df2
# Out:
#                    A         B         C         D         E      F
# 2014-01-02 -1.455026  1.143917 -0.085159  1.180756  0.869964    one
# 2014-01-03  0.609824 -1.056103  0.530066  0.619100 -0.739971    two
# 2014-01-04  0.489072  0.571512 -0.758280  1.313670  1.353612  three
# 2014-01-05 -0.398659 -0.247843 -0.129677  1.438823 -0.804592   four

# %%
#<help:dataframe_isin_filter>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df2 = df.copy()
df2['F']=['one', 'two','three','four']
df2
df2[df2['F'].isin(['two','four'])]
# Out:
#                    A         B         C         D         E     F
# 2014-01-03 -0.971678 -0.182320 -0.406658 -2.492440 -0.595151   two
# 2014-01-05 -0.685441 -0.004397  0.995123 -1.495693  1.033594  four

# %% [markdown]
# ##Setting
# You can automatically align the data by the indexes.

# %%
#<help:dataframe_set_column>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
s1 = pd.Series([1,2,3,4,5,6],index=pd.date_range('20140302',periods=6))
s1
df['F'] = s1
s1
# Out:
# 2014-03-02    1
# 2014-03-03    2
# 2014-03-04    3
# 2014-03-05    4
# 2014-03-06    5
# 2014-03-07    6
# Freq: D, dtype: int64

# %%
#<help:dataframe_set_value_label>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.at[dates[0],'B'] = 0
df
# Out:
#                    A         B         C         D         E
# 2014-01-02 -1.137343  0.000000 -1.132527 -0.471786 -0.120211
# 2014-01-03  0.535933  0.916380 -1.196852  0.983677 -1.456074
# 2014-01-04 -0.922428 -0.810478 -1.088242  0.592469 -0.058294
# 2014-01-05  1.710081  0.635618  0.054669  2.075116 -0.926636

# %%
#<help:dataframe_set_value_position>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.iat[0,1] = 0
df
# Out:
#                    A         B         C         D         E
# 2014-01-02  1.389385  0.000000 -0.972099  1.054792  0.159809
# 2014-01-03  1.479512 -0.601326 -1.243301 -0.077779  1.800919
# 2014-01-04 -1.057616 -0.352962  1.258624 -1.249029 -1.047936
# 2014-01-05 -1.064052 -1.436882 -0.617823  0.216856 -1.073398

# %%
#<help:dataframe_set_assign_numpy_array>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.loc[:,'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D         E
# 2014-01-02 -1.707422  0.627554  0.353344  5 -0.966533
# 2014-01-03 -0.381553  0.069893  1.150265  5  0.835555
# 2014-01-04 -0.712882 -2.548086 -0.973569  5 -1.528691
# 2014-01-05 -0.670966 -0.544256  0.685233  5  0.090955

# %%
#<help:dataframe_where_setting>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C         D         E
# 2014-01-02 -0.949935 -0.477544 -0.377754 -0.093197 -0.460348
# 2014-01-03 -0.307706 -0.070314 -0.359661 -0.662774 -0.236885
# 2014-01-04 -1.158574 -0.641019 -0.517590 -1.275215 -0.474596
# 2014-01-05 -1.025845 -0.055788 -1.073009 -1.284259 -0.436726

# %% [markdown]
# ##Missing Data
# Reindexing allows to change/add/delete an index on an axis. This returns a copy of the data.

# %%
#<help:dataframe_reindex_for_missing_data>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df1 = df.reindex(index=dates[0:4],columns=list(df.columns) + ['F'])
df1.loc[dates[0]:dates[1],'F'] = 1
df1
# Out:
#                    A         B         C         D         E   F
# 2014-01-02  1.390954  0.573134  1.220969  0.992696 -1.648570   1
# 2014-01-03  1.543715  0.900803 -0.338822  0.960075 -1.960974   1
# 2014-01-04 -0.077641 -0.473721 -2.115656  0.053293  0.214948 NaN
# 2014-01-05  0.051866  0.950803 -0.351182 -1.971169 -0.589844 NaN

# %% [markdown]
# Drop the rows that don't contain data.

# %%
#<help:dataframe_drop_rows_missing_data>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df1 = df.reindex(index=dates[0:4],columns=list(df.columns) + ['F'])
df1.loc[dates[0]:dates[1],'F'] = 1
df1.dropna(how='any')
# Out:
#                    A         B         C         D         E  F
# 2014-01-02  2.403767  1.164463 -0.778697  0.397697 -1.615812  1
# 2014-01-03 -0.699814 -0.134163 -0.074183  0.998247 -0.046299  1

# %% [markdown]
# Fill the cells that have missing data with a given value.

# %%
#<help:dataframe_fill_missing_data>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df1 = df.reindex(index=dates[0:4],columns=list(df.columns) + ['F'])
df1.loc[dates[0]:dates[1],'F'] = 1
df1.fillna(value=3)
# Out:
#                    A         B         C         D         E  F
# 2014-01-02 -0.969432 -0.972317 -1.133962  0.112403 -0.189992  1
# 2014-01-03 -0.467054 -0.691867  0.832034  0.783218  0.901610  1
# 2014-01-04  1.537552 -0.047097 -0.939855  1.326867 -0.000227  3
# 2014-01-05 -1.563843 -0.306246  0.933490 -0.065401  0.771833  3

# %% [markdown]
# Convert the table to boolean values if the cell is NaN, True if not False.

# %%
#<help:dataframe_boolean_if_values_Nan>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df1 = df.reindex(index=dates[0:4],columns=list(df.columns) + ['F'])
df1.loc[dates[0]:dates[1],'F'] = 1
pd.isnull(df1)
# Out:
#                 A      B      C      D      E      F
# 2014-01-02  False  False  False  False  False  False
# 2014-01-03  False  False  False  False  False  False
# 2014-01-04  False  False  False  False  False   True
# 2014-01-05  False  False  False  False  False   True

# %% [markdown]
# ###Append
#
# Add rows.

# %%
#<help:dataframe_append_rows>
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -1.105876  0.573884  0.801123  0.103183
# 1  1.741355 -1.246085  1.362352  0.145879
# 2 -1.144801 -1.019509  0.395401 -1.391006
# 3 -0.013194 -1.374491  0.301319  0.060784
# 4 -0.632668 -0.593188 -1.398845  0.040006
# 5  0.911086  1.898355  0.961342  0.093673
# 6 -1.258209 -0.175149  0.869913  0.719288
# 7 -3.158776 -0.361077 -0.416061  0.531232
# 8 -0.013194 -1.374491  0.301319  0.060784

# %% [markdown]
# ##Groupby
# Refers to:
#
# * **Splitting** the data into groups based on some criteria
#
# * **Applying** a function to each group independently
#
# * **Combining** the results into a data structure

# %%
#<help:dataframe_groupby>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})
print(df)
df.groupby('A').first()
# Out:
#      A      B         C         D
# 0  foo    one  0.141951 -0.653596
# 1  bar    one -0.240134 -1.093146
# 2  foo    two -0.115776  0.194599
# 3  bar  three -1.851969  0.626809
# 4  foo    two -0.409942  0.971827
# 5  bar    two  0.794642  0.086239
# 6  foo    one  0.808964 -0.737832
# 7  foo  three -0.701696  1.166038
#        B         C         D
# A
# bar  one -0.240134 -1.093146
# foo  one  0.141951 -0.653596

# %% [markdown]
# Group a column and add them to a cumulative sum.

# %%
#<help:dataframe_groupby_and_sum>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -2.126346  1.893680
# foo -1.421486 -1.838922

# %% [markdown]
# Group multiple columns and add them.

# %%
#<help:dataframe_groupby_sum_multiple>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8), 'D' : np.random.randn(8)})
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.236328 -0.240471
#     three -0.223292  0.944650
#     two   -2.451452  1.421662
# foo one   -0.051023 -1.344165
#     three  2.373895  0.883232
#     two   -0.429872 -1.016410

# %% [markdown]
# #File Management
# ##Read from Files
#
# Read data from a CSV or TXT file using the read_csv function. By default, it assumes that the fields are comma-separated. If the data is indexed, you can select the column to be used as an index, eg. `index_col=0`. The complete parameter list is in the [documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.io.parsers.read_csv.html).

# %%
#<help:read_csv>
import pandas as pd
import numpy as np
medals_df = pd.read_csv('/resources/medals.csv')
medals_df = medals_df.dropna()
medals_df.tail()
# Out:
#       Year   City   Sport Discipline  NOC            Event Event gender  \
# 2306  2006  Turin  Skiing  Snowboard  USA        Half-pipe            M
# 2307  2006  Turin  Skiing  Snowboard  USA        Half-pipe            W
# 2308  2006  Turin  Skiing  Snowboard  USA        Half-pipe            W
# 2309  2006  Turin  Skiing  Snowboard  USA  Snowboard Cross            M
# 2310  2006  Turin  Skiing  Snowboard  USA  Snowboard Cross            W
#
#        Medal
# 2306  Silver
# 2307    Gold
# 2308  Silver
# 2309    Gold
# 2310  Silver

# %% [markdown]
# Drop `Nan` values by using `.dropna()`.

# %%
#<help:read_csv_dropna>
import pandas as pd
import numpy as np
medals_df = pd.read_csv('/resources/medals.csv', parse_dates=True)
medals_df = medals_df.dropna()
medals_df.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %% [markdown]
# To better facilitate working with datetime data, `read_csv()` and `read_table()`, use the keyword arguments `parse_dates` and `date_parser` to allow users to specify a variety of columns and date/time formats to turn the input text data into datetime objects.
#
# The simplest case is to just pass in `parse_dates=True`.

# %% [markdown]
# Use the `index_col=0` to place the first column as the index. Use any number to `n-1` to set it as an index.

# %%
#<help:read_csv_dates>
import pandas as pd
import numpy as np
dates = pd.date_range('20140102',periods=5)
df = pd.DataFrame(np.random.randn(5,5),index=dates,columns=list('ABCDE'))
djs = df.to_csv('dates.csv',index=True,header=True)
dja = pd.read_csv('/resources/dates.csv', parse_dates=True, index_col=0)
dja.head()
# Out:
#                    A         B         C         D         E
# 2014-01-02  0.341960  1.384801 -1.860173 -1.742180  0.631732
# 2014-01-03  1.420105  0.742977 -0.118261 -0.806000  1.405389
# 2014-01-04 -0.625556  0.381157 -1.338116 -0.370333  0.439752
# 2014-01-05 -1.222666  1.316150  0.159955 -2.100424  1.375340
# 2014-01-06  0.106463  0.534723  1.300391  1.829471  0.543412

# %% [markdown]
# ##Save to a file
# Use the `to_csv` function to save the data to a `csv` or `txt` file. The full parameter list is in the [documentation](http://pandas.pydata.org/pandas-docs/version/0.15.1/generated/pandas.DataFrame.to_csv.html).

# %%
#<help:save_csv>
import pandas as pd
import numpy as np
names = ['Michael','Jessica','Mary','John','Ashley']
births = [1168, 255, 177, 878, 973]
BabyDataSet = zip(names,births)
df = pd.DataFrame(data = BabyDataSet, columns=['Names', 'Births'])
df
df.to_csv('births.csv',index=False,header=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 2 columns):
# Names     5 non-null object
# Births    5 non-null int64
# dtypes: int64(1), object(1)

# %% [markdown]
# ##To JSON
# A Series or DataFrame can be converted to a valid JSON string. Use `to_json` with optional parameters:
#
# * `path_or_buf` : the pathname or buffer to write the output. This can be `None` in which case a JSON string is returned.
#
# * `orient` :
#
#     Series :
#         * default is index
#         * allowed values are {split, records, index}
#     DataFrame
#         * default is columns
#         * allowed values are {split, records, index, columns, values}
#     The format of the JSON string:
#
#
# |  command         |       params                                                            |
# |-----------|-----------|
# |`split`	|dict like {index -> [index], columns -> [columns], data -> [values]}|
# |`records`	|list like [{column -> value}, ... , {column -> value}]|
# |`index`	|dict like {index -> {column -> value}}|
# |`columns`	|dict like {column -> {index -> value}}|
# |`values`	|just the values array|
#
# * `date_format` : string, type of date conversion, ‘epoch’ for timestamp, ‘iso’ for ISO8601.
#
# * `double_precision` : The number of decimal places to use when encoding floating point values, default is 10.
#
# * `force_ascii` : force encoded string to be ASCII, default is True.
#
# * `date_unit` : The time unit to encode to, governs timestamp and ISO8601 precision. One of ‘s’, ‘ms’, ‘us’ or ‘ns’ for seconds, milliseconds, microseconds and nanoseconds respectively. Default is ‘ms’.
#
# * `efault_handler` : The handler to call if an object cannot otherwise be converted to a suitable format for JSON. Takes a single argument, which is the object to convert, and returns a serializable object.

# %%
#<help:save_json>
import pandas as pd
import numpy as np
dfj = pd.DataFrame(np.random.randn(5, 2), columns=list('AB'))
json = dfj.to_json('random.json')
json

# %% [markdown]
# **The same applies for reading a JSON file**. The most important [parameters](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_json.html) are:
#
# * `convert_dates` : a list of columns to parse for dates; If True, then try to parse date-like columns, default is `True`.
#
# * `eep_default_dates` : boolean, default `True`. If parsing dates, then parse the default date-like columns.
#
# * `numpy` : direct decoding to numpy arrays. default is False; Supports numeric data only, although labels may be non-numeric. Also note that the JSON ordering MUST be the same for each term if `numpy=True`.
#
# * `precise_float` : boolean, default False. Set to enable usage of higher precision (strtod) function when decoding string to double values. Default (`False`) is to use fast but less precise builtin functionality.
#
# * `ate_unit` : string, the timestamp unit to detect if converting dates. Default is `None`. By default the timestamp precision will be detected. If this is not desired then pass one of `‘s’, ‘ms’, ‘us’` or `‘ns’` to force timestamp precision to seconds, milliseconds, microseconds or nanoseconds respectively.

# %%
#<help:read_json>
import pandas as pd
import numpy as np
jsondf = pd.read_json('/resources/random.json')
jsondf
# Out:
#           A         B
# 0  0.198005 -0.138050
# 1 -0.046135  0.969846
# 2  0.129937  1.175885
# 3 -0.564145 -0.546930
# 4 -0.490073 -0.090153

# %% [markdown]
# ##Pickling
# All pandas objects are equipped with `to_pickle` methods which use Python’s `cPickle` module to save data structures to disk using the pickle format.
# The `read_pickle` function in the pandas namespace can be used to load any pickled pandas object (or any other pickled object) from file.

# %%
#<help:pickling>
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(5,5),index=None,columns=list('ABCDE'))
df.to_pickle('foo.pkl')
pd.read_pickle('/resources/foo.pkl')
# Out:
#           A         B         C         D         E
# 0 -1.124159  0.421760 -1.518763  1.597252  0.326345
# 1 -0.776085 -0.291160 -1.382761 -0.643777 -1.603261
# 2  0.096898 -0.354124 -0.342316  1.839349 -0.802606
# 3  0.575954 -0.320522 -0.794509  0.384421 -0.722213
# 4  0.016271  1.357025  0.306015 -0.311486  0.324469

# %% [markdown]
# ##SQL Queries
# The `pandas.io.sql` module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependencies on DB-specific APIs. Database abstraction is provided by SQLAlchemy, which needs to be installed. In addition you will need a driver library for your database.
#
# **Required**
#
# `!pip install SQLAlchemy`
#
# The key functions are:
#
# | Function                                       | Description                                          |
# |------------------------------------------------|------------------------------------------------------|
# |read_sql_table(table_name, con[, schema, ...])	 |Read SQL database table into a DataFrame.             |
# |read_sql_query(sql, con[, index_col, ...])      |Read SQL query into a DataFrame.                      |
# |read_sql(sql, con[, index_col, ...])	         |Read SQL query or database table into a DataFrame.    |
# |DataFrame.to_sql(name, con[, flavor, ...])      |Write records stored in a DataFrame to a SQL database.|

# %%
#<help:sql_store_read>
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
engine = create_engine('sqlite:///:memory:')
df = pd.DataFrame(np.random.randn(5,5),index=None,columns=list('ABCDE'))
df.to_sql('data', engine)
pd.read_sql_table('data', engine, index_col='index')
# Out:
#               A         B         C         D         E
# index
# 0      0.102863  0.005536  0.740207 -1.890874  1.034769
# 1     -2.008746  1.443343 -1.199818 -0.294680  0.431065
# 2     -0.310882 -0.460812 -0.802473  0.443571 -0.346301
# 3     -1.987784  0.626944  0.085253  0.504165 -0.721021
# 4      0.545457  1.772235  2.133399 -0.233076 -2.200551

# %% [markdown]
# ####SQL Query

# %%
#<help:sql_query>
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
engine = create_engine('sqlite:///:memory:')
df = pd.DataFrame(np.random.randn(5,5),index=None,columns=list('ABCDE'))
df.to_sql('data', engine)
pd.read_sql_query('SELECT * FROM data', engine)
# Out:
#    index         A         B         C         D         E
# 0      0  0.963235  1.001309  0.676588  2.105329  0.094949
# 1      1  0.502408  1.532740  0.044703 -1.049283 -0.503526
# 2      2  0.036638  2.313746  1.473786  0.470251  0.355086
# 3      3 -0.076542 -0.159439 -0.546321  0.417212 -0.595337
# 4      4 -0.554529  0.552038 -0.092915 -0.537565 -0.938416

# %% [markdown]
# #Plot a Series or DataFrame with pandas, using matplotlib to display
# Create/Feed a Series or DataFrame, and plot it simply by using ```plot()```
#
# **matplotlib is needed to display a plot:**
#
# Add in your header:
#
# `import matplotlib.pyplot as plt`
#
# `%matplotlib inline`
#
# End your code with:
#
# `plt.show()`
#
# The entire parameter list for `plot` is:
#
# `DataFrame.plot(data, x=None, y=None, kind='line', ax=None, subplots=False, sharex=True, sharey=False, layout=None, figsize=None, use_index=True, title=None, grid=None, legend=True, style=None, logx=False, logy=False, loglog=False, xticks=None, yticks=None, xlim=None, ylim=None, rot=None, fontsize=None, colormap=None, table=False, yerr=None, xerr=None, secondary_y=False, sort_columns=False, **kwds)`
#
# **Use default pandas formatting**
#
# Pandas provides a good color and line format, more visually appealing compared to matplotlib.
#
# `pd.options.display.mpl_style = 'default'`

# %%
#<help:plot_series>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.options.display.mpl_style = 'default'
import numpy as np
s = pd.Series([1,4,3,6,5,8])
s.plot()
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# The same formatting applies for DataFrames.

# %%
#<help:plot_dataframe>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
pd.options.display.mpl_style = 'default'
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df.plot()
plt.show()

# %% [markdown]
# Select a column to plot only that column in a DataFrame.

# %%
#<help:plot_dataframe_one_column>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
pd.options.display.mpl_style = 'default'
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df['A'].plot()
plt.show()

# %% [markdown]
# The kind keyword argument of plot() accepts a handful of values for plots other than the default line plot. These include:
#
# * `'bar'` or `'barh'` for bar plots
#
# * `'box'` for boxplot
#
# * `'kde'` or `'density'` for density plots
#
# * `'area'` for area plots
#
# * `'scatter'` for scatter plots
#
# * `'hexbin'` for hexagonal bin plots
#
# * `.hist()` for histogram
#
# * `.pie()`  for pie plots

# %% [markdown]
# ##Scatter Plot
# ```.plot(kind='scatter' ```

# %%
#<help:plot_scatter>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.options.display.mpl_style = 'default'
import numpy as np
dates = pd.date_range('20140102',periods=6)
df = pd.DataFrame(np.random.randn(6,6),index=dates,columns=list('ABCDEF'))
df.plot(kind='scatter', x= 'A', y='B', color = 'g')
plt.show()

# %% [markdown]
# For plotting multiple columns, use the `ax` keyword.

# %%
#<help:plot_multiple_scatter>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.options.display.mpl_style = 'default'
import numpy as np
df = pd.DataFrame(np.random.rand(25, 4), columns=['A', 'B', 'C', 'D'])
ax = df.plot(kind='scatter', x='A', y='D',
             color='Blue', label='Group 1')
df.plot(kind='scatter', x='B', y='C',
        color='Green', label='Group 2', ax=ax)
plt.show()

# %% [markdown]
# ##Hexbin Plot
# Useful for when a scatter plot is has too many data points.
# Use `kind='hexbin'`.
#
# Control the number of hexagons in the x direction with `gridsize`, defaults to 100.

# %%
#<help:plot_hexbin>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.options.display.mpl_style = 'default'
import numpy as np
df = pd.DataFrame(np.random.rand(900, 3), columns=['A', 'B', 'C'])
df['B'] = df['B'] + np.arange(900)
df.plot(kind='hexbin', x='C', y='B', gridsize=20)
plt.show()

# %% [markdown]
# ##Bar Plot
# ```.plot(kind='bar',```

# %%
#<help:plot_bar_vertical>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.options.display.mpl_style = 'default'
import numpy as np
dates = pd.date_range('20141102',periods=8)
df = pd.DataFrame(np.random.randn(8,8),index=dates,columns=list('ABCDEFGH'))

df.plot(kind='bar', x= 'C', y='B', color='c')
plt.show()

# %% [markdown]
# ##Stacked Bar Plot
# ```stacked = 'True'```

# %%
#<help:plot_stacked_bar>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.options.display.mpl_style = 'default'
import numpy as np
df= pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])
df.plot(kind='bar', stacked='True')
plt.show()

# %% [markdown]
# ##Horizontal bar plot
# ```.plot(kind='barh', ```

# %%
#<help:plot_bar_horizontal>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.options.display.mpl_style = 'default'
import numpy as np
dates = pd.date_range('20140902',periods=8)
df = pd.DataFrame(np.random.randn(8,8),index=dates,columns=list('ABCDEFGH'))
df.plot(kind='barh', x= 'C', y='F')
plt.show()

# %% [markdown]
# ##Density Plot
# ```kind='kde'```

# %%
#<help:plot_kde_density>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.options.display.mpl_style = 'default'
import numpy as np
ser = pd.Series(np.random.randn(1000))
ser.plot(kind='kde')
plt.show()

# %% [markdown]
# ##Histograms (pandas 0.15.0)
# ```.hist()```

# %% [markdown]
# ```#<help:plot_hist>
#
# import matplotlib.pyplot as plt
#
# %matplotlib inline
#
# import pandas as pd
#
# pd.options.display.mpl_style = 'default'
#
# import numpy as np
#
# ser = pd.Series(np.random.randn(1000))
#
# ser.hist()
#
# plt.show()
# ```

# %% [markdown]
# A histogram can be stacked using `stacked=True`. The bin size can be customized by setting `bins=N`.

# %% [markdown]
# ```#<help:plot_hist_stacked>
# import matplotlib.pyplot as plt
# %matplotlib inline
# import pandas as pd
# import numpy as np
# pd.options.display.mpl_style = 'default'
# df4 = pd.DataFrame({'A': np.random.randn(500) + 1, 'B': np.random.randn(500),
#                  'C': np.random.randn(500) - 1}, columns=['A', 'B', 'C'])
# plt.figure();
# df4.plot(kind='hist', stacked=True, bins=25)
# plt.show()
# ```

# %% [markdown]
# Other keywords can be used, like `orientation='horizontal'` and `cumulative=True`

# %% [markdown]
# ```#<help:plot_hist_cumulative_horizontal>
# import matplotlib.pyplot as plt
# %matplotlib inline
# import pandas as pd
# import numpy as np
# pd.options.display.mpl_style = 'default'
# df4 = pd.DataFrame({'A': np.random.randn(500) + 1, 'B': np.random.randn(500),
#                  'C': np.random.randn(500) - 1}, columns=['A', 'B', 'C'])
# plt.figure();
# df4['A'].plot(kind='hist', orientation='horizontal', cumulative=True)
# plt.show()
# ```

# %% [markdown]
# ## Scatter Plot for a Series

# %%
#<help:plot_scatter_series>
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
np.random.seed(1974)

# Generate Data
num = 20
x, y = np.random.random((2, num))
labels = np.random.choice(['a', 'b', 'c'], num)
df = pd.DataFrame(dict(x=x, y=y, label=labels))

groups = df.groupby('label')

# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, label=name)
ax.legend()

plt.show()

# %% [markdown]
# ##Box Plot
# ```.boxplot()```

# %%
#<help:plot_box_dataframe>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
daf = pd.DataFrame(np.random.rand(10,5))
bp= daf.boxplot()
plt.show()
# Out:
# /home/notebook/ka_env/lib/python2.7/site-packages/pandas/tools/plotting.py:2380: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Bootstrap Plot
# These visually assess the uncertainty of a statistic.

# %%
#<help:plot_bootstrap_series>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
from pandas.tools.plotting import bootstrap_plot
data = pd.Series(np.random.rand(1500))
bootstrap_plot(data, size=50, samples= 300, color='m')
plt.show()

# %% [markdown]
# ##Pie Chart
# `kind='pie'`
#
# **Note:**
# Use the `labels` and `colors` keywords to specify the labels and colors of each wedge.
# (Note the lack of “s” on those). This is to be consistent with `matplotlib.pyplot.pie()`.

# %%
#<help:plot_pie>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
series = pd.Series(3* np.random.rand(4), index=['a','b','c','d'], name='Series')
series.plot(kind='pie', labels=['AA', 'BB', 'CC', 'DD'], colors=['m', 'g', 'y', 'c'], figsize=(6,6))
plt.show()

# %% [markdown]
# ##Area Plot
# `kind='area'`
#
# Stacked by default, produce an unstacked plot with `stacked=False`

# %%
#<help:plot_area_stacked>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
df=pd.DataFrame(np.random.rand(10,4), columns=['a', 'b', 'c', 'd'])
df.plot(kind='area')
plt.show()

# %%
#<help:plot_area_unstacked>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
df=pd.DataFrame(np.random.rand(10,4), columns=['a', 'b', 'c', 'd'])
df.plot(kind='area', stacked=False)
plt.show()

# %% [markdown]
# # Create Multiple Charts in Pre-defined Layout
#
# Each Series in a DataFrame can be plotted on a different axis with the subplots keyword:
#
# ```df.plot(subplots=True, figsize=(6, 6));```

# %% [markdown]
# ##Line Plot

# %%
#<help:plot_multiple_line>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'

df = pd.DataFrame(np.random.randn(100, 4), columns=list('ABCD'))
df.plot(subplots=True, figsize=(6, 6));
plt.show()

# %%
#<help:plot_multiple_line>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
from pandas.tools.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
df.plot(subplots=True, figsize=(6, 6));
plt.show()

# %% [markdown]
# ##Histograms

# %%
#<help:plot_multiple_hist>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
df = pd.DataFrame({'A': np.random.randn(1000) + 1, 'B': np.random.randn(1000), 
                   'C': np.random.randn(1000) - 1}, columns = ['A','B','C'])
plt.figure()
df.diff().hist(color='r', alpha=0.5, bins=30)
plt.show()

# %% [markdown]
# ##Stratified Boxplot
# Use the ``` by ``` keyword to create groupings.

# %%
#<help:plot_multiple_stratified_box>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
df = pd.DataFrame(np.random.rand(10,2), columns=['Column1','Column2'])
df['X']= pd.Series(['A','A','A','A','A','B','B','B','B','B'])
plt.figure()
bp = df.boxplot(by = 'X')
plt.show()

# %% [markdown]
# ##Scatter Matrix
# You can create a scatter plot matrix using the ```scatter_matrix``` method in pandas.tools.plotting.

# %%
#<help:plot_scatter_matrix>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
from pandas.tools.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
plt.show()

# %% [markdown]
# ##Multiple Bar Charts
# From
# https://datasciencelab.wordpress.com/2013/12/21/beautiful-plots-with-pandas-and-matplotlib/

# %%
#<help:plot_multiple_bar>
import pandas as pd
pd.options.display.mpl_style = 'default'
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.lines import Line2D 
 
countries = ['France','Spain','Sweden','Germany','Finland','Poland','Italy',
             'United Kingdom','Romania','Greece','Bulgaria','Hungary',
             'Portugal','Austria','Czech Republic','Ireland','Lithuania','Latvia',
             'Croatia','Slovakia','Estonia','Denmark','Netherlands','Belgium']
extensions = [547030,504782,450295,357022,338145,312685,301340,243610,238391,
              131940,110879,93028,92090,83871,78867,70273,65300,64589,56594,
              49035,45228,43094,41543,30528]
populations = [63.8,47,9.55,81.8,5.42,38.3,61.1,63.2,21.3,11.4,7.35,
               9.93,10.7,8.44,10.6,4.63,3.28,2.23,4.38,5.49,1.34,5.61,
               16.8,10.8]
life_expectancies = [81.8,82.1,81.8,80.7,80.5,76.4,82.4,80.5,73.8,80.8,73.5,
                    74.6,79.9,81.1,77.7,80.7,72.1,72.2,77,75.4,74.4,79.4,81,80.5]
data = {'Extension' : pd.Series(extensions, index=countries), 
        'Population' : pd.Series(populations, index=countries),
        'Life Expectancy' : pd.Series(life_expectancies, index=countries)}
 
df = pd.DataFrame(data)
df = df.sort('Life Expectancy')
fig, axes = plt.subplots(nrows=3, ncols=1)
for i, c in enumerate(df.columns):
    df[c].plot(kind='bar', ax=axes[i], figsize=(12, 10), title=c)
fig.tight_layout()    
plt.show()

# %% [markdown]
# ##Multiple Pie Charts
# `subplots=True`

# %%
#<help:plot_multiple_pie>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
df = pd.DataFrame(3 * np.random.rand(4, 2), index=['a', 'b', 'c', 'd'], columns=['x', 'y'])
df.plot(kind='pie', subplots=True, labels=['A', 'B', 'C', 'D'], colors=['b', 'g', 'r', 'y'], figsize=(8,4))
plt.show()

# %% [markdown]
# ## Bar Chart for a Pandas DataFrame "group by"
#
# Group info and plot it in a Bar chart. Csv file and code taken from:
#
# https://github.com/jvns/pandas-cookbook/blob/v0.1/data/bikes.csv

# %%
#<help:plot_groupby_bar>
import pandas as pd
pd.options.display.mpl_style = 'default'
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
bikes = pd.read_csv('/resources/bikes.csv', 
                    sep=';', encoding='latin1', 
                    parse_dates=['Date'], dayfirst=True, 
                    index_col='Date')
# Add the weekday column
berri_bikes = bikes[['Berri 1']]
berri_bikes['weekday'] = berri_bikes.index.weekday

# Add up the number of cyclists by weekday, and plot!
weekday_counts = berri_bikes.groupby('weekday').aggregate(sum)
weekday_counts.index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_counts.plot(kind='bar')
plt.show()

# %% [markdown]
# ##Groupby Line Plot

# %%
#<help:plot_groupby_line>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

pd.options.display.mpl_style = 'default'
dates = pd.date_range('20140102',periods=4)
df = pd.DataFrame(np.random.randn(4,5),index=dates,columns=list('ABCDE'))
df = df.groupby('B').cumsum()
df.plot()
plt.show()

# %% [markdown]
# ##Error Bars
# Use matplotlib's implementation `yerr` or `xerr` for error margins.

# %%
#<help:plot_error_bar>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
pd.options.display.mpl_style = 'default'
# Generate the data
ix3 = pd.MultiIndex.from_arrays([['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b'], ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar']], names=['letter', 'word'])
df3 = pd.DataFrame({'data1': [3.5, 2.9, 4.1, 3.2, 2.1, 4.8, 3.9, 2.4], 'data2': [6.2, 5.6, 7.3, 5.1, 4.7, 5.8, 6.1, 5.9]}, index=ix3)
# Group by index labels and take the means and standard deviations for each group
gp3 = df3.groupby(level=('letter', 'word'))
means = gp3.mean()
errors = gp3.std()
fig, ax = plt.subplots()
means.plot(yerr=errors, ax=ax, kind='bar')
plt.title('Error Bar')
plt.show()

# %% [markdown]
# #Pandas Plot Formatting
# * show how to configure usage of Pandas nice looking graphs
# ```
# pandas.options.display.mpl_style = 'default' # use pandas default style for plots
# ```
#
# **pandas uses the matplotlib api for most of its formatting including colors, labels titles and layout.**
#
# For Title:
# * `plt.title('My Title')`
#
# Axis Labels:
# * `plt.xlabel('xlabel')`
# * `plt.ylabel('ylabel')`
#
# You can customize `fontsize` and `color`.

# %%
#<help:plot_formatting_title_color>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
pd.options.display.mpl_style = 'default'
dates = pd.date_range('20141102',periods=5)
df = pd.DataFrame(np.random.randn(5,5),index=dates,columns=list('ABCDE'))
df['A'].plot(color='g')

plt.title('My Title', fontsize=20)

plt.xlabel('X Axis', fontsize=16, color='r')
plt.ylabel('Y Axis', fontsize=16, color ='m')
plt.show()

# %% [markdown]
# ##Add a Table at the bottom of a Plot
# * `table=True`
#
# Another option is to transpose the data in a print method manually
# * `table=np.round(df.T, 2)`
# This also rounds to two decimal places to increase the numbers visibility.

# %%
#<help:plot_formatting_table_bottom>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
pd.options.display.mpl_style = 'default'
fig, ax = plt.subplots(1, 1)
df = pd.DataFrame(np.random.rand(5, 3), columns=['A', 'B', 'C'])
ax.get_xaxis().set_visible(False)   # Hide Ticks)
df.plot(table=np.round(df.T, 2), ax=ax)
plt.title('Table at the Bottom')
plt.show()

# %% [markdown]
# Add the table to the chart itself with `pandas.tools.plotting.table` and add it to `matplotlib.Axes`.

# %%
#<help:plot_formatting_table_in>
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
pd.options.display.mpl_style = 'default'

from pandas.tools.plotting import table
df = pd.DataFrame(np.random.rand(5, 3), columns=['A', 'B', 'C'])
fig, ax = plt.subplots(1, 1)
table(ax, np.round(df.describe(), 2),
      loc='upper right', colWidths=[0.1, 0.1, 0.1])
df.plot(ax=ax, ylim=(0, 2), legend=None)
plt.title('Table in the Plot')
plt.show()

# %% [markdown]
# ##Add a legend
# Use `plt.legend('My Legend', loc='best')` to add a legend.
#
# You can remove the legend by setting `df.plot(legend=None)`.

# %%
#<help:plot_formatting_legend>
import pandas as pd
import numpy as np
pd.options.display.mpl_style = 'default'
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
             columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure()
df.plot()
plt.title('With Title')
plt.legend(loc='best')

# %% [markdown]
# ###Colormap
# Having many data sets when plotting serie makes it hard to distiguish them from each other. A colormap helps contrast the colors avoiding repetition. Use the [colormap](http://wiki.scipy.org/Cookbook/Matplotlib/Show_colormaps) hues to better differentiate data.

# %%
#<help:plot_formatting_colormap>
import pandas as pd
import numpy as np
pd.options.display.mpl_style = 'default'
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.DataFrame(np.random.randn(1000, 10))
df = df.cumsum()
plt.figure()
df.plot(colormap='Set1')
plt.title('Set1 Colormap')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ##Log-Scale axis
# Use  `logy`, or `logx` or `loglog =True` in `plot()` to get a log scale in the each or both axes (in the case of loglog).

# %%
#<help:plot_formatting_log_axes>
import pandas as pd
import numpy as np
pd.options.display.mpl_style = 'default'
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
ts = pd.Series(np.random.randn(2000))
ts = np.exp(ts.cumsum())
ts.plot(logy=True)
plt.show()

# %% [markdown]
# ##Multi-Plot Formatting
#
# The layout of subplots can be specified by the `layout` keyword, which accepts `rows` and `columns` as parameters. The layout keyword can be used in hist and boxplot also. If input is invalid, a `ValueError` will be raised.
#
# The number of axes which can be contained by rows x columns specified by `layout` must be larger than the number of required subplots. If `layout` can contain more axes than required, blank axes are not drawn. Similar to a numpy array’s reshape method, you can use `-1` for one dimension to automatically calculate the number of rows or columns needed, given the other.

# %%
#<help:plot_formatting_multiple>
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
pd.options.display.mpl_style = 'default'
from pandas.tools.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
df.plot(subplots=True, figsize=(6, 6), sharex=False);

plt.show()
