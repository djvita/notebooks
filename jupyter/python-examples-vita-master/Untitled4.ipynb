# %%
# !pip install matplotlib --upgrade
# Out:
# Downloading/unpacking matplotlib from https://pypi.python.org/packages/source/m/matplotlib/matplotlib-1.4.2.tar.gz#md5=7d22efb6cce475025733c50487bd8898
# ...
#   Running setup.py (path:/home/notebook/ka_env/build/matplotlib/setup.py) egg_info for package matplotlib
# ...
#     Edit setup.cfg to change the build options
#
#     BUILDING MATPLOTLIB
#                 matplotlib: yes [1.4.2]
#                     python: yes [2.7.6 (default, Mar 22 2014, 22:59:56)  [GCC
#                             4.8.2]]
#                   platform: yes [linux2]
#
#     REQUIRED DEPENDENCIES AND EXTENSIONS
#                      numpy: yes [version 1.9.1]
#                        six: yes [using six version 1.8.0]
#                   dateutil: yes [using dateutil version 2.2]
#                       pytz: yes [using pytz version 2014.9]
#                    tornado: yes [using tornado version 3.2]
#                  pyparsing: yes [using pyparsing version 2.0.3]
# ...
